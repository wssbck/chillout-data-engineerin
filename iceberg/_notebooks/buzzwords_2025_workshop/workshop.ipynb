# %% [markdown]
# ### Prepare the Environment and Clients
#
# * pyiceberg
# * Spark

# %%
from pyiceberg.catalog import load_catalog


catalog = load_catalog("rest")

# recreate namespace if needed
try:
    catalog.create_namespace("workshop")
except Exception as e:
    pass
catalog.list_namespaces()

# %%
from pyspark.sql import SparkSession


spark = (
    SparkSession.builder
        .config(
            "spark.sql.extensions",
            "org.projectnessie.spark.extensions.NessieSparkSessionExtensions, org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions"
        )
        .config("spark.sql.catalog.iceberg", "org.apache.iceberg.spark.SparkCatalog")
        .config("spark.sql.catalog.iceberg.io-impl", "org.apache.iceberg.aws.s3.S3FileIO")
        .config("spark.sql.catalog.iceberg.type", "rest")
        .config("spark.sql.catalog.iceberg.uri", "http://lakekeeper:8181/catalog/")
        .config("spark.sql.catalog.iceberg.warehouse", "iceberg")
        .config("spark.sql.catalog.iceberg.ref", "main")
        .config("spark.sql.catalog.iceberg.cache-enabled", False)
        .getOrCreate()
)
spark.sparkContext.setLogLevel('ERROR')

spark.sql("""
    SHOW SCHEMAS
""").show()

# %% [markdown]
# ### Define the Table

# %%
# cleanup if required

spark.sql("""
DROP TABLE IF EXISTS iceberg.workshop.atable
""")

# %%
spark.sql("""
CREATE TABLE IF NOT EXISTS iceberg.workshop.atable (
    id string COMMENT 'random id',
    name string COMMENT 'a name',
    value int COMMENT 'integer with some numerical value',
    timestamp timestamp COMMENT 'a timestamp column'
)
PARTITIONED BY (years(timestamp))
TBLPROPERTIES (
    'format-version'='2'
)
""")

# %%
# describe the created table

spark.sql("""
DESCRIBE EXTENDED iceberg.workshop.atable
""").toPandas()

# %%
# insert some data

import random
import uuid

from datetime import datetime
from pyspark.sql import Row
from pyspark.sql.functions import to_timestamp


df = spark.createDataFrame([
    Row(
        id=str(uuid.uuid4()),
        name=random.choice(["Ariel", "Georgina", "Tom", "Ulma"]),
        value=random.randint(100, 999),
        timestamp=datetime.fromisoformat("2024-12-01T07:32:18")
    ),
    Row(
        id=str(uuid.uuid4()),
        name=random.choice(["Ariel", "Georgina", "Tom", "Ulma"]),
        value=random.randint(100, 999),
        timestamp=datetime.fromisoformat("2025-01-02T09:11:23")
    ),
])

df.writeTo("iceberg.workshop.atable").append()

# %%
spark.sql("""
SELECT *, _file, _partition
FROM iceberg.workshop.atable
ORDER BY name
""").toPandas()

# %%
spark.sql("""
SELECT *
FROM iceberg.workshop.atable.history
""").show(1000, False)

# %%
spark.sql("""
--SELECT *
SELECT content, file_path, record_count, partition
FROM iceberg.workshop.atable.data_files
""").toPandas()

# %% [markdown]
# ### Partitioning

# %%
# change partition layout

spark.sql("""
ALTER TABLE iceberg.workshop.atable
DROP PARTITION FIELD years(timestamp)
""")

# %%
spark.sql("""
ALTER TABLE iceberg.workshop.atable
ADD PARTITION FIELD bucket(2, id)
""").toPandas()

# %%
spark.sql("""
DESCRIBE EXTENDED iceberg.workshop.atable
""").toPandas()

# %%
# anything changed?

spark.sql("""
--SELECT *
SELECT content, file_path, record_count, partition
FROM iceberg.workshop.atable.data_files
""").toPandas()

# %%
# write more data

df = spark.createDataFrame([
    Row(
        id=str(uuid.uuid4()),
        name=random.choice(["Ariel", "Georgina", "Tom", "Ulma"]),
        value=random.randint(100, 999),
        timestamp=datetime.fromisoformat("2024-12-01T07:32:18")
    ),
    Row(
        id=str(uuid.uuid4()),
        name=random.choice(["Ariel", "Georgina", "Tom", "Ulma"]),
        value=random.randint(100, 999),
        timestamp=datetime.fromisoformat("2025-01-02T09:11:23")
    ),
])

df.writeTo("iceberg.workshop.atable").append()

# %%
# what about now?

spark.sql("""
--SELECT *
SELECT content, file_path, record_count, partition
FROM iceberg.workshop.atable.data_files
""").toPandas()

# %%
# partitions?

spark.sql("""
SELECT *
FROM iceberg.workshop.atable.partitions
""").toPandas()

# %% [markdown]
# ### Snapshots

# %%
# list snapshots

spark.sql("""
SELECT snapshot_id
-- SELECT snapshot_id, committed_at
FROM iceberg.workshop.atable.snapshots
ORDER BY committed_at
""").show(50, False)

# %%
# query older snapshots

spark.sql("""
SELECT *
FROM iceberg.workshop.atable VERSION AS OF 8872617564754325900
""").toPandas()

# %%
# query metadata of older snapshots

spark.sql("""
SELECT *
FROM iceberg.workshop.atable.data_files VERSION AS OF 8872617564754325900
""").toPandas()

# %%
# create tags

spark.sql("""
ALTER TABLE iceberg.workshop.atable
CREATE TAG `TAG1`
AS OF VERSION 8872617564754325900
""").toPandas()

# %%
# list refs

spark.sql("""
SELECT * FROM
iceberg.workshop.atable.refs
""").toPandas()

# %%
# query a tag

spark.sql("""
SELECT * FROM
iceberg.workshop.atable.tag_TAG1
""").toPandas()

# %%
# retire some snapshots

spark.sql("""
CALL iceberg.system.expire_snapshots(
	table => 'iceberg.workshop.atable', snapshot_ids => ARRAY(752082346590731591)
)
""").toPandas()

# %%
# query snapshots

spark.sql("""
SELECT * FROM
iceberg.workshop.atable.snapshots
ORDER BY committed_at
""").toPandas()

# %% [markdown]
# ### Libraries

# %%
# perform a scan of the table with Polars

import polars as pl


table = catalog.load_table("workshop.atable")

storage_options = {
    "s3.endpoint": "http://minio:9000",
    "s3.region": "eu-central-1",
    "s3.access-key-id": "minioadmin",
    "s3.secret-access-key": "minioadmin",
}

pl_table = pl.scan_iceberg(table.metadata_location, storage_options=storage_options)

# %%
# query it with Polars

pl.sql(
    """
    SELECT * FROM pl_table
    """
).collect()

# %%
# Lazy Frame?

pl.sql(
    """
    SELECT * FROM pl_table
    """
)

# %%
# configure DuckDB to work with Iceberg and MinIO

import duckdb


duckdb.sql("""
INSTALL iceberg;
LOAD iceberg;
INSTALL httpfs;
LOAD httpfs;

SET s3_endpoint='minio:9000';
SET s3_access_key_id='minioadmin';
SET s3_secret_access_key='minioadmin';
SET s3_region='eu-central-1';
SET s3_use_ssl=false;
SET s3_url_style='path';
""")

# %%
# query with DuckDB

duckdb.sql(f"SELECT * FROM iceberg_scan('{table.metadata_location}')")

# %%
# PyIceberg exploration

dir(table.inspect)

# %%
table.inspect.refs().to_pandas()

# %% [markdown]
# ### Data Files

# %%
spark.sql("""
SELECT * FROM
iceberg.workshop.atable.data_files
""").toPandas()

# %%
# Delete some data

spark.sql("""
DELETE FROM
iceberg.workshop.atable
WHERE name = 'Ariel'
""").toPandas()

# %%
# are files gone?

spark.sql("""
SELECT * FROM
iceberg.workshop.atable.data_files
""").toPandas()

# %%
# yes, but also no

spark.sql("""
SELECT * FROM
iceberg.workshop.atable.all_data_files
""").toPandas()

# %% [markdown]
# ### Metadata

# %%
# and now with Spark
# tables to use: history, metadata_log_entries, snapshots, entries, files, manifests, partitions,
# also (DANGER!) all_data_files, all_entries, all_manifests

spark.sql("""
SELECT * FROM
iceberg.workshop.atable.metadata_log_entries
""").toPandas()
